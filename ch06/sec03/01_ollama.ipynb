# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? please explain 한국어로 설명해줘"})

# %%
answer
# Out:
# 'Okay, here\'s an explanation of LangChain in Korean, broken down step-by-step:\n\n**LangChain이란 무엇인가? (LangChain-이란 무엇인가?)**\n\nLangChain은 대규모 언어 모델 (Large Language Models, LLM)을 사용하여 더욱 강력하고 복잡한 애플리케이션을 만들도록 돕는 프레임워크입니다. 좀 더 쉽게 말하면, LLM을 사용하는 앱을 훨씬 더 쉽게 만들 수 있도록 도와주는 도구 상자와 같습니다.\n\n**1. LLM (대규모 언어 모델) 이란? (LLM-이란?)**\n\n* **LLM**은 엄청나게 많은 텍스트 데이터를 학습한 인공지능 모델입니다.  예를 들어, ChatGPT나 Google의 Bard와 같은 모델들이 LLM에 해당됩니다. 이 모델들은 텍스트를 생성하고, 질문에 답하고, 텍스트를 번역하는 등 다양한 작업을 수행할 수 있습니다.\n* **핵심:** LLM은 단일 모델이 아니라, 텍스트를 이해하고 생성하는 능력을 갖춘 거대한 신경망입니다.\n\n**2. LangChain이 제공하는 것들 (LangChain-이 제공하는 것들)**\n\nLangChain은 LLM을 활용하여 다음과 같은 작업을 더 쉽게 하도록 설계되었습니다:\n\n* **체인 (Chains):** LangChain의 핵심 개념입니다.  체인은 LLM을 다른 구성 요소와 연결하여 복잡한 작업을 수행합니다. 예를 들어,  "사용자가 질문을 하면, 관련된 정보를 검색하고, 그 정보를 기반으로 답변을 생성하는" 과정을 체인으로 만들 수 있습니다.\n* **데이터 연결 (Data Connection):** LLM은 학습 데이터에만 의존합니다. LangChain은 외부 데이터 소스(데이터베이스, 웹사이트, 문서 등)에 연결하여 LLM이 더 신선하고 관련 있는 정보를 활용하도록 합니다.  \n* **메모리 (Memory):** LLM은 대화의 이전 내용을 기억하지 못합니다. LangChain은 대화의 흐름을 유지하기 위해 LLM에 "메모리"를 제공하여 이전 대화 내용을 저장하고 활용할 수 있도록 합니다.\n* **에이전트 (Agents):**  에이전트는 LLM을 사용하여 특정 작업을 수행하기 위한 도구들을 활용합니다. 예를 들어, 에이전트는 웹 검색 도구를 사용하거나, 계산기를 사용하거나, 다른 LLM을 호출하여 작업을 완료할 수 있습니다.\n\n**3. 왜 LangChain을 사용하는가? (LangChain-을 사용하는가?)**\n\n* **개발 시간 단축:** 복잡한 LLM 애플리케이션을 처음부터 구축하는 것보다 LangChain을 사용하면 훨씬 빠르게 개발할 수 있습니다.\n* **유연성 및 확장성:**  LangChain은 다양한 LLM 및 데이터 소스와 함께 사용할 수 있어 애플리케이션을 쉽게 수정하고 확장할 수 있습니다.\n* **커뮤니티 및 생태계:**  활발한 커뮤니티와 다양한 도구들이 존재하여 개발자가 필요한 도움을 받거나 새로운 기능을 쉽게 사용할 수 있습니다.\n\n**요약 (요약)**\n\nLangChain은 LLM을 활용하여 더 스마트하고 강력한 애플리케이션을 만드는 데 도움이 되는 프레임워크입니다. LLM을 쉽게 연결하고, 외부 데이터에 연결하고, 대화의 흐름을 유지하고, LLM을 통해 다양한 도구를 활용할 수 있도록 돕습니다.\n\n---\n\nDo you want me to elaborate on a specific aspect of LangChain, such as a particular chain type, or perhaps give an example of how it\'s used?'
