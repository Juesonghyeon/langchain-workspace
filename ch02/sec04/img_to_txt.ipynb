# %%
print("Hello")
# Out:
# 'ch02 (Python 3.14.0)'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 'ipykernel'을(를) Python 환경에 설치합니다.
#
# 명령: 'd:/jsh/langchain-workspace/ch02/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
