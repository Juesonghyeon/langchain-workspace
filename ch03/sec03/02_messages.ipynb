# %% [markdown]
# ### 메세지 (Message)

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage, AIMessage, SystemMessage

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

system_msg = SystemMessage("You are a helpful assistant.")
human_msg = HumanMessage("Hello, how are you?")

# Use with chat models
messages = [system_msg, human_msg]
response = model.invoke(messages)  # Returns AIMessage
# Out:
# d:\jsh\langchain-workspace\ch03\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
response
# Out:
# AIMessage(content="Hello! I'm doing great, thank you for asking. I'm a large language model, so I don't experience feelings in the same way humans do, but I'm always ready and eager to assist you.\n\nHow can I help you today? What's on your mind?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--2b000d47-1a5a-4d8c-8d72-55ac27474717-0', usage_metadata={'input_tokens': 13, 'output_tokens': 62, 'total_tokens': 75, 'input_token_details': {'cache_read': 0}})

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    # 시스템 메시지: 모델에게 '시(詩) 전문가' 역할을 부여합니다.
    SystemMessage("당신은 시 전문가입니다"),
    
    # 인간 메시지: 사용자 입력으로, '봄에 관한 하이쿠를 작성해달라'는 요청입니다.
    HumanMessage("봄에 관한 하이쿠를 작성해줘"),
    
    # AI 메시지: 모델이 이전에 응답했던 내용으로 대화 기록에 추가됩니다.
    AIMessage("벚꽃이 피어나네...")
]
# 이 메시지 목록을 모델에 전달하여 다음 응답을 얻습니다.
response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content='\n새들이 노래하네...\n봄이 왔구나.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e7c20848-09c0-4357-8cf9-c7c6c7d6aca5-0', usage_metadata={'input_tokens': 25, 'output_tokens': 12, 'total_tokens': 37, 'input_token_details': {'cache_read': 0}})

# %%
# Dictionary format
messages = [
    {"role": "system", "content": "당신은 시 전문가입니다"},
    {"role": "user", "content": "봄에 관한 하이쿠를 작성해줘"},
    {"role": "assistant", "content": "벚꽃이 피어나네..."}
]
response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content='\n산들바람에 흩날리며\n봄의 노래 부르네', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--b67bd663-ab8c-4482-b6e5-01cbb151786d-0', usage_metadata={'input_tokens': 25, 'output_tokens': 17, 'total_tokens': 42, 'input_token_details': {'cache_read': 0}})

# %%
from langchain.messages import SystemMessage, HumanMessage

# 비교의 편의상 답변 길이 제한을 추가합니다.
system_msg = SystemMessage("당신은 도움이 되는 코딩 보조 전문가입니다. 500자 이내로 답변하세요.")

messages = [
    system_msg, 
    HumanMessage("REST API를 어떻게 만드나요?")
]

# 이 메시지 목록을 모델에 전달하여 응답을 얻습니다.
response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content='REST API를 만드는 방법은 다음과 같습니다.\n\n1.  **설계:**\n    *   **리소스 정의:** API가 다룰 데이터(예: 사용자, 게시물, 상품)를 명확히 정의합니다. 각 리소스는 고유한 URI(Uniform Resource Identifier)로 식별됩니다.\n    *   **HTTP 메서드 활용:** 각 리소스에 대해 어떤 작업을 수행할지 결정하고, 이에 맞는 HTTP 메서드(GET, POST, PUT, DELETE 등)를 선택합니다.\n        *   `GET`: 데이터 조회\n        *   `POST`: 데이터 생성\n        *   `PUT`: 데이터 전체 수정\n        *   `PATCH`: 데이터 부분 수정\n        *   `DELETE`: 데이터 삭제\n    *   **요청/응답 형식:** 클라이언트와 서버 간에 데이터를 주고받을 형식(주로 JSON)을 결정합니다.\n    *   **상태 코드:** 요청 성공/실패 여부를 나타내는 HTTP 상태 코드(200 OK, 201 Created, 400 Bad Request, 404 Not Found 등)를 적절히 사용합니다.\n\n2.  **구현:**\n    *   **프로그래밍 언어 및 프레임워크 선택:** Node.js (Express), Python (Flask, Django), Java (Spring), Ruby (Rails) 등 다양한 언어와 프레임워크를 사용할 수 있습니다.\n    *   **라우팅 설정:** 특정 URI와 HTTP 메서드 요청을 처리할 함수(핸들러)를 연결합니다.\n    *   **데이터 처리:** 요청된 데이터를 파싱하고, 비즈니스 로직을 수행하며, 필요한 경우 데이터베이스와 상호작용합니다.\n    *   **응답 생성:** 처리 결과를 HTTP 상태 코드와 함께 JSON 형식으로 클라이언트에 반환합니다.\n\n3.  **테스트 및 배포:**\n    *   **테스트:** Postman, Insomnia와 같은 도구를 사용하여 API의 각 엔드포인트가 예상대로 작동하는지 테스트합니다.\n    *   **배포:** 개발된 API를 서버에 배포하여 외부에서 접근 가능하도록 합니다.\n\n**핵심 원칙:**\n\n*   **무상태(Stateless):** 서버는 클라이언트의 이전 요청에 대한 정보를 저장하지 않습니다. 모든 요청은 독립적입니다.\n*   **클라이언트-서버 분리:** 클라이언트와 서버는 서로 독립적으로 개발 및 수정될 수 있습니다.\n*   **캐싱 가능(Cacheable):** 응답은 캐싱 가능하도록 설계하여 성능을 향상시킬 수 있습니다.\n\n이러한 단계를 거쳐 RESTful한 API를 구축할 수 있습니다.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--d44340f1-00bd-4ef5-b12c-53442071a56a-0', usage_metadata={'input_tokens': 32, 'output_tokens': 574, 'total_tokens': 606, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# REST API를 만드는 방법은 다음과 같습니다.
#
# 1.  **설계:**
#     *   **리소스 정의:** API가 다룰 데이터(예: 사용자, 게시물, 상품)를 명확히 정의합니다. 각 리소스는 고유한 URI(Uniform Resource Identifier)로 식별됩니다.
#     *   **HTTP 메서드 활용:** 각 리소스에 대해 어떤 작업을 수행할지 결정하고, 이에 맞는 HTTP 메서드(GET, POST, PUT, DELETE 등)를 선택합니다.
#         *   `GET`: 데이터 조회
#         *   `POST`: 데이터 생성
#         *   `PUT`: 데이터 전체 수정
#         *   `PATCH`: 데이터 부분 수정
#         *   `DELETE`: 데이터 삭제
#     *   **요청/응답 형식:** 클라이언트와 서버 간에 데이터를 주고받을 형식(주로 JSON)을 결정합니다.
#     *   **상태 코드:** 요청 성공/실패 여부를 나타내는 HTTP 상태 코드(200 OK, 201 Created, 400 Bad Request, 404 Not Found 등)를 적절히 사용합니다.
#
# 2.  **구현:**
#     *   **프로그래밍 언어 및 프레임워크 선택:** Node.js (Express), Python (Flask, Django), Java (Spring), Ruby (Rails) 등 다양한 언어와 프레임워크를 사용할 수 있습니다.
#     *   **라우팅 설정:** 특정 URI와 HTTP 메서드 요청을 처리할 함수(핸들러)를 연결합니다.
#     *   **데이터 처리:** 요청된 데이터를 파싱하고, 비즈니스 로직을 수행하며, 필요한 경우 데이터베이스와 상호작용합니다.
#     *   **응답 생성:** 처리 결과를 HTTP 상태 코드와 함께 JSON 형식으로 클라이언트에 반환합니다.
#
# 3.  **테스트 및 배포:**
#     *   **테스트:** Postman, Insomnia와 같은 도구를 사용하여 API의 각 엔드포인트가 예상대로 작동하는지 테스트합니다.
#     *   **배포:** 개발된 API를 서버에 배포하여 외부에서 접근 가능하도록 합니다.
#
# **핵심 원칙:**
#
# *   **무상태(Stateless):** 서버는 클라이언트의 이전 요청에 대한 정보를 저장하지 않습니다. 모든 요청은 독립적입니다.
# *   **클라이언트-서버 분리:** 클라이언트와 서버는 서로 독립적으로 개발 및 수정될 수 있습니다.
# *   **캐싱 가능(Cacheable):** 응답은 캐싱 가능하도록 설계하여 성능을 향상시킬 수 있습니다.
#
# 이러한 단계를 거쳐 RESTful한 API를 구축할 수 있습니다.

# %%
from langchain.messages import SystemMessage, HumanMessage

# 시스템 메시지: 모델의 역할, 응답 스타일, 지침을 상세하게 설정합니다.
system_msg = SystemMessage("""
당신은 웹 프레임워크에 전문성을 가진 시니어 파이썬 개발자입니다.
응답은 반드시 Flask를 사용한 REST API의 핵심 CRUD 구현 방법 5가지를 요약한 표로 시작하십시오.
이 표 다음에 전체 코드 예시와 당신의 추론 과정을 상세히 설명하십시오.
설명은 간결하지만 철저하게 하십시오.
500자 이내로 답변하세요.
""")

# 전체 메시지 목록: 시스템 지침과 사용자 질문을 포함합니다.
messages = [
    system_msg, # 모델의 상세 역할과 행동 방식을 지시하는 시스템 메시지
    HumanMessage("REST API를 어떻게 만드나요?") # 사용자가 모델에 하는 질문
]

# 이 메시지 목록을 모델에 전달하여 응답을 얻습니다.
response = model.invoke(messages)

# %%
print(response.content)
# Out:
# ## Flask를 사용한 REST API 핵심 CRUD 구현
#
# | 기능        | HTTP 메소드 | URL 경로 예시 | 설명                                        |
# | ----------- | ----------- | ------------- | ------------------------------------------- |
# | 생성 (Create) | POST        | `/items`      | 새 항목 생성                                |
# | 읽기 (Read)   | GET         | `/items/<id>` | 특정 항목 조회 (전체 조회: `/items`)        |
# | 수정 (Update) | PUT         | `/items/<id>` | 특정 항목 전체 수정                         |
# | 삭제 (Delete) | DELETE      | `/items/<id>` | 특정 항목 삭제                              |
#
# ---
#
# ## Flask REST API 예제 코드
#
# ```python
# from flask import Flask, request, jsonify
#
# app = Flask(__name__)
#
# # 간단한 인메모리 데이터베이스 역할
# items = {}
# next_id = 1
#
# @app.route('/items', methods=['POST'])
# def create_item():
#     global next_id
#     data = request.get_json()
#     if not data or 'name' not in data:
#         return jsonify({'error': 'Invalid input'}), 400
#
#     item_id = next_id
#     items[item_id] = {'id': item_id, 'name': data['name']}
#     next_id += 1
#     return jsonify(items[item_id]), 201
#
# @app.route('/items', methods=['GET'])
# def get_items():
#     return jsonify(list(items.values()))
#
# @app.route('/items/<int:item_id>', methods=['GET'])
# def get_item(item_id):
#     item = items.get(item_id)
#     if item:
#         return jsonify(item)
#     return jsonify({'error': 'Item not found'}), 404
#
# @app.route('/items/<int:item_id>', methods=['PUT'])
# def update_item(item_id):
#     item = items.get(item_id)
#     if not item:
#         return jsonify({'error': 'Item not found'}), 404
#
#     data = request.get_json()
#     if not data or 'name' not in data:
#         return jsonify({'error': 'Invalid input'}), 400
#
#     item['name'] = data['name']
#     return jsonify(item)
#
# @app.route('/items/<int:item_id>', methods=['DELETE'])
# def delete_item(item_id):
#     if item_id in items:
#         del items[item_id]
#         return jsonify({'message': 'Item deleted successfully'})
#     return jsonify({'error': 'Item not found'}), 404
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# ---
#
# ## 코드 설명 및 추론
#
# 이 코드는 Flask를 사용하여 기본적인 RESTful API를 구축하는 방법을 보여줍니다.
#
# 1.  **초기 설정**:
#     *   `Flask` 객체를 생성하고, 간단한 데이터 저장을 위해 `items` 딕셔너리와 `next_id` 변수를 사용합니다. 실제 애플리케이션에서는 데이터베이스를 사용합니다.
#
# 2.  **`POST /items` (Create)**:
#     *   클라이언트로부터 JSON 데이터를 받아옵니다 (`request.get_json()`).
#     *   필수 필드(`name`)가 있는지 확인합니다.
#     *   새로운 `item_id`를 할당하고, 데이터를 `items` 딕셔너리에 저장합니다.
#     *   생성된 항목과 함께 `201 Created` 상태 코드를 반환합니다.
#
# 3.  **`GET /items` (Read All)**:
#     *   `items` 딕셔너리의 모든 값을 리스트로 변환하여 반환합니다.
#
# 4.  **`GET /items/<id>` (Read One)**:
#     *   URL 경로에서 `item_id`를 정수형으로 받습니다.
#     *   `items.get(item_id)`를 사용하여 항목을 찾습니다.
#     *   항목이 존재하면 반환하고, 없으면 `404 Not Found`를 반환합니다.
#
# 5.  **`PUT /items/<id>` (Update)**:
#     *   수정할 항목을 찾습니다.
#     *   새로운 JSON 데이터를 받아옵니다.
#     *   항목의 `name`을 업데이트합니다.
#     *   업데이트된 항목을 반환합니다.
#
# 6.  **`DELETE /items/<id>` (Delete)**:
#     *   `item_id`에 해당하는 항목을 `items` 딕셔너리에서 삭제합니다.
#     *   성공 메시지를 반환합니다. 항목이 없으면 `404`를 반환합니다.
#
# 7.  **`app.run(debug=True)`**:
#     *   개발 서버를 실행합니다. `debug=True`는 코드 변경 시 서버 자동 재시작 및 디버깅 정보를 제공합니다.
#
# 이 예제는 REST API의 CRUD 연산을 Flask의 라우팅 및 요청/응답 처리를 통해 구현하는 기본 원리를 보여줍니다.
