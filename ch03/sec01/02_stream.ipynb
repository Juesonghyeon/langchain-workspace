# %%
import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0, 
    google_api_key=gemini_api_key
)

# %%
response = llm.invoke("대한민국의 수도는?")

# %%
response
# Out:
# AIMessage(content='대한민국의 수도는 **서울**입니다.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--1956997e-26a9-47f5-950e-f1b09815f03c-0', usage_metadata={'input_tokens': 7, 'output_tokens': 30, 'total_tokens': 37, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 20}})

# %%
response.content
# Out:
# '대한민국의 수도는 **서울**입니다.'

# %%
response.response_metadata
# Out:
# {'prompt_feedback': {'block_reason': 0, 'safety_ratings': []},
#  'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'safety_ratings': [],
#  'grounding_metadata': {},
#  'model_provider': 'google_genai'}

# %%
response.usage_metadata
# Out:
# {'input_tokens': 7,
#  'output_tokens': 30,
#  'total_tokens': 37,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 20}}

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0, # 창의성 0.0 ~ 2.0
    google_api_key=gemini_api_key
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = llm.invoke(prompt)

# %%
response.content
# Out:
# '나는 새로운 에이전트를 만들었다. 먼저 `PromptTemplate`으로 명확한 지시와 성격을 부여하고, `Chain`으로 복잡한 사고 흐름을 엮었다. 그리고 `Memory`를 탑재해 과거 대화를 기억하고 맥락을 유지하게 했다. 어느 날, 사무실 네트워크가 갑자기 마비되었다. 에이전트는 학습된 적 없는 상황이었지만, `Memory`에 저장된 과거 시스템 로그와 `PromptTemplate`의 문제 해결 지침을 `Chain`으로 연결하여, 숨겨진 백업 라우터를 찾아내 네트워크를 복구시켰다. 모두가 놀랐다.'

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=2,
    google_api_key=gemini_api_key
)

# %%
response = llm.invoke(prompt)

# %%
response.content
# Out:
# "새로운 에이전트 '솔로몬'을 만들었다. 현명한 지침을 위해 `PromptTemplate`으로 사고의 뼈대를 세웠고, 여러 기능을 유기적으로 연결하는 `Chain`을 신중하게 엮었다. 대화 맥락을 기억하게 `Memory`까지 탑재하여, 완벽한 비서라 자부했다.\n\n첫 임무는 서류 정리였지만, 갑자기 연구실 온도가 치솟으며 이상 작동 경고등이 깜빡였다. 솔로몬은 놀란 연구원들 대신, 쌓인 `Memory`와 `Chain`을 활용, 냉각 시스템의 숨겨진 보조 회로를 스스로 찾아냈다. 즉각적으로 비상 냉각을 시작하여 예측 불가능했던 폭발 위험을 성공적으로 막아냈다. 모두가 솔로몬의 예상을 뛰어넘는 문제 해결 능력에 경악했다."

# %% [markdown]
# ### 스트리밍 출력

# %%
response = llm.stream(prompt)

# %%
response
# Out:
# <generator object BaseChatModel.stream at 0x000001DB65C26700>

# %%
next(response)
# Out:
# AIMessageChunk(content='LangChain 개발자인 나는 새로운 에이전트를 빚어내고 있었다. 먼저, 정확한 질문을 위한 `PromptTemplate`으로 생각의 씨앗을 심고, 이어서 지식과 행동을 연결하는 단단한 `Chain', additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--5bbbd14f-e9b6-4f3e-bd51-b04dc1d77dbd', usage_metadata={'input_tokens': 124, 'output_tokens': 1197, 'total_tokens': 1321, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1146}})

# %%
for token in response:
    print(token.content, end="", flush=True)
# Out:
# `을 엮었다. 그리고 지나온 대화를 잊지 않도록 `Memory` 회로를 장착하여 자율성을 부여했다. 마침내 에이전트가 눈을 떴다.
#
# 어느 날, 복잡한 네트워크 장애로 시스템이 마비되었다. 모두가 헤매던 그때, 에이전트가 외쳤다. "불규칙한 외부 API 호출 패턴 감지! 방화벽 구성 변경이 원인입니다!" 예상치 못한 정확한 진단에 모두 놀랐고, 문제 해결에 성공했다.
